# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
N=1000
a=np.linspace(-100,100,N)
b=np.linspace(-100,100,N)
x=np.linspace(-100,100,N)
#np.random.shuffle(x)
y=np.linspace(-100,100,N)
#np.random.shuffle(y)
X, Y = np.meshgrid(x, y)

#eta=(Y**2)*X-(X**2)*(Y)
#neta=(X**3)+(Y**3)

eta=a*X + b*Y
neta=-(b*X)+(a*Y)
#plt.scatter(eta,neta)

# %%
fig = plt.figure()
 
# syntax for 3-D plotting
ax = plt.axes(projection ='3d')
 
# syntax for plotting
ax.plot_surface(X, Y, neta, cmap ='viridis', edgecolor ='green')
plt.show()

# %%
domain_space=[-1,1]
a=np.linspace(domain_space[0],domain_space[1],N)
#np.random.shuffle(a)
b=np.zeros(N)
c=np.linspace(domain_space[0],domain_space[1],N)
#np.random.shuffle(c)
A,C=  np.meshgrid(a, c)

dx_dt_1=(C)/(A)


dx_dt_2=(-C)/(A)

x=np.linspace(domain_space[0],domain_space[1],N)
fig = plt.figure()
# syntax for 3-D plotting
ax = plt.axes(projection ='3d')
# syntax for plotting
#ax.plot_surface(A, C, dx_dt_1)
ax.contour3D(A, C, dx_dt_1,50, cmap='viridis')
#ax.plot_wireframe(X, Y, dx_dt_2)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Contour Plot for characteristic direction')
plt.show()

# %%
ax.view_init(20, 10)
fig

# %%
dx_dt_1=(C)/(A)

# %%
fig = plt.figure()
# syntax for 3-D plotting
ax = plt.axes(projection ='3d')
# syntax for plotting
#ax.plot_surface(A, C, dx_dt_2)
ax.contour3D(X, Y, dx_dt_2,50, cmap='viridis')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('3D')
plt.show()

# %%
N=1000
domain_space=[-2,2]
x=np.linspace(domain_space[0],domain_space[1],N)
y=np.linspace(domain_space[0],domain_space[1],N)
X,Y=  np.meshgrid(x, y)
a=np.ones(N)
#np.random.shuffle(a)
b=np.zeros(N)
c=np.linspace(-1,1,N)
#np.random.shuffle(c)
A,C=  np.meshgrid(a, c)
#dx_dt_1=(b+np.sqrt((b**2)-4*a*c))/(2*a)

dx_dt_1=np.sqrt(-4*A*C)/(2*A)

#dx_dt_2=(b-np.sqrt((b**2)-4*a*c))/(2*a)

dx_dt_2=-np.sqrt(-4*A*C)/(2*A)

x=np.linspace(domain_space[0],domain_space[1],N)
#plt.plot(x,dx_dt_1,label='a')
#plt.plot(x,dx_dt_1,label='b')
fig = plt.figure()
 
# syntax for 3-D plotting
ax = plt.axes(projection ='3d')
 
# syntax for plotting
ax.plot_surface(X, Y, dx_dt_1)
ax.set_title('3D')
plt.show()

# %%
plt.contourf(X, Y, dx_dt_1)
plt.show()

# %%
X

# %%
Y.shape

# %%
plt.plot(x,dx_dt_1[:,1])

# %%
A=np.array([[2,-4],[0,-1]])

# %%
A
# Out:
# array([[ 2, -4],
#        [ 0, -1]])

# %%
A.shape
# Out:
# (2, 2)

# %%
C=np.linalg.inv(A)

# %%
D=np.array([[-0.5,2],[0,1]])

# %%
D
# Out:
# array([[-0.5,  2. ],
#        [ 0. ,  1. ]])

# %%
C
# Out:
# array([[ 0.5, -2. ],
#        [-0. , -1. ]])

# %%
print(np.matmul(C,A))

# %%
print(np.matmul(A,D))

# %%
np.linalg.det(A)

# %%
27/(16*120)

# %%
16*120

# %%
120*16

# %%
3**5

# %%
Dis=4*(X**2)*(Y**2)

# %%
fig = plt.figure()
 
# syntax for 3-D plotting
ax = plt.axes(projection ='3d')
 
# syntax for plotting
#ax.plot_surface(X, Y, Dis)
ax.contour3D(X, Y, Dis,50, cmap='binary')
ax.set_title('For real values of x,y')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('function')
plt.show()

# %%
import cmath

a = 1
b = 2
c = 1

# calculate the discriminant
d = (b**2) - (4*a*c)

# find two solutions
sol1 = (-b-cmath.sqrt(d))/(2*a)
sol2 = (-b+cmath.sqrt(d))/(2*a)

print('The solution are {0} and {1}'.format(sol1,sol2))
# Out:
# The solution are (-1+0j) and (-1+0j)

# %%
lambd=-1

# %%
a*lambd**2 + b*lambd +c
# Out:
# 0
