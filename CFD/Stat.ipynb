# %% [markdown]
# ![image.png](attachment:7540a158-f38c-448c-ba54-36170eebaa57.png)

# %% [markdown]
# ![image.png](attachment:5e07ccc4-76a5-4b11-a035-c5a16a333ce0.png)

# %%
s1=1.4
s2=1.9
n1=6
n2=6
y1=102.4
y2=

# %%
import numpy as np

# %%
s1=9.51
s2=6.15
x1=57.2
x2=47.6
n1=30
n2=35
df=n1+n2-2
sp=np.sqrt(((n1-1)*s1**2 + (n2-1)*s2**2)/(n1+n2-2))

# %%
df
# Out:
# 63

# %%
x¯1=57.2; s1=9.51

x¯2=47.6; s2=6.15

# %% [markdown]
# ![image.png](attachment:cb3311ce-81f1-41bc-908d-6c48a7f94ee1.png)

# %%
(()-())/(np.sqrt((sp**2/n1)+(sp**2/n2))

# %% [markdown]
# ![image.png](attachment:dd243723-3d60-4e71-a465-eed94d63fc99.png)

# %%
s1=11.5
s2=11.4
x1=18.3
x2=15.4
n1=20
n2=20
df=n1+n2-2
sp=((n1-1)*s1**2 + (n2-1)*s2**2)/(n1+n2-2)

# %%
sp
# Out:
# 131.105

# %%
0.51986+0.17287

# %% [markdown]
# ![image.png](attachment:22c7f9a9-4b9c-4cca-89e0-d987d0177d63.png)

# %%
t=(x1-x2)/(np.sqrt((sp**2)/(n1) +(sp**2)/(n2)))

# %%
t
# Out:
# 0.06994855432278174
